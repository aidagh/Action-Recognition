# %% [markdown]
# <a href="https://colab.research.google.com/github/aidagh/Action-Recognition/blob/main/resnext50_32x4d_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi #show selected GPU
# Out:
# Sun Nov 22 15:18:27 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#Import Libraries
import shutil
import cv2
import numpy as np
import os
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
# !pip install efficientnet_pytorch
# !pip install pretrainedmodels
# Out:
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.0-cp36-none-any.whl size=16031 sha256=31036a6b856c8ca29db61c9d082e15b6345b6d4e1ec61f2806a31b8ef6b4a250
#   Stored in directory: /root/.cache/pip/wheels/e9/c6/e1/7a808b26406239712cfce4b5ceeb67d9513ae32aa4b31445c6
# Successfully built efficientnet-pytorch
# ...
#      |████████████████████████████████| 61kB 3.2MB/s
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60964 sha256=dacbf2f3249ce8ff8d8e75476edcf58326ebd9f4228c99859cd1b9b7e4a608fe
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# Successfully built pretrainedmodels
# ...

# %%
#Download Dataset from Kaggle
# !wget -cO - 'https://storage.googleapis.com/kaggle-data-sets/965291/1632787/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20201122%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20201122T151459Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...' > raw_data.zip
# Out:
# --2020-11-22 15:18:36--  https://storage.googleapis.com/kaggle-data-sets/965291/1632787/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20201122%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20201122T151459Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.204.128, 64.233.188.128, 64.233.189.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.204.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2529619836 (2.4G) [application/zip]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   2.36G  67.4MB/s    in 25s
#
# 2020-11-22 15:19:01 (95.5 MB/s) - written to stdout [2529619836/2529619836]

# %%
#Clone GitHub profile (CODES)
# !git clone 'https://github.com/mhrah7495/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition'
# Out:
# fatal: destination path 'View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition' already exists and is not an empty directory.

# %%
#UNZIP the dataset
shutil.unpack_archive('raw_data.zip', 'View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/raw_data', 'zip')

# %%
cd '/content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu'
# Out:
# /content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu

# %%
# Remove the bad skeleton 
# !python get_raw_denoised_data.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing S016C001P021R001A023
# Processing S016C001P021R001A024
# Processing S016C001P021R001A025
# Processing S016C001P021R001A026
# Processing S016C001P021R001A027
# Processing S016C001P021R001A028
# Processing S016C001P021R001A029
# Processing S016C001P021R001A030
# Processing S016C001P021R001A031
# Processing S016C001P021R001A032
# Processing S016C001P021R001A033
# Processing S016C001P021R001A034
# Processing S016C001P021R001A035
# Processing S016C001P021R001A036
# Processing S016C001P021R001A037
# Processing S016C001P021R001A038
# Processing S016C001P021R001A039
# Processing S016C001P021R001A040
# Processing S016C001P021R001A041
# Processing S016C001P021R001A042
# Processing S016C001P021R001A043
# Processing S016C001P021R001A044
# Processing S016C001P021R001A045
# Processing S016C001P021R001A046
# Processing S016C001P021R001A047
# Processing S016C001P021R001A048
# Processing S016C001P021R001A049
# ...

# %%
# Transform the skeleton to the center of the first frame
# !python seq_transformation.py --dataset='CV'
# Out:
# tcmalloc: large alloc 10184040448 bytes == 0x71188000 @  0x7fbc78ab1001 0x7fbc765d5765 0x7fbc76639bb0 0x7fbc7663ba4f 0x7fbc766d2048 0x50a4a5 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fbc786acbf7 0x5b259a
# tcmalloc: large alloc 6437347328 bytes == 0x2d09ca000 @  0x7fbc78aaf1e7 0x7fbc765d55e1 0x7fbc76639c78 0x7fbc76639d93 0x7fbc766c4ed6 0x7fbc766c5338 0x50c19e 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fbc786acbf7 0x5b259a
# tcmalloc: large alloc 3407765504 bytes == 0x2d09ca000 @  0x7fbc78aaf1e7 0x7fbc765d55e1 0x7fbc76639c78 0x7fbc76639d93 0x7fbc766c4ed6 0x7fbc766c5338 0x50c19e 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fbc786acbf7 0x5b259a

# %%
cd ..
# Out:
# /content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data

# %%
cd ..
# Out:
# /content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition

# %%
#Run CNN code (ResNet50)
# !python  va-cnn.py --model VA --train 1 --case=1 --max_epoches=30 --model_name='resnext50_32x4d'
# Out:
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to /root/.cache/torch/hub/checkpoints/resnext50_32x4d-7cdf4587.pth
# 100% 95.8M/95.8M [00:00<00:00, 195MB/s]
# Total Trainable Params: 25028904
# tcmalloc: large alloc 6437347328 bytes == 0x7fc64e4de000 @  0x7fc88a4f81e7 0x7fc8877785e1 0x7fc8877dcc78 0x7fc88777be61 0x551555 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588c8b 0x7fc8288f2e5c 0x59478c 0x59fd0e 0x5576d8 0x50c19e 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508f37 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03
# tcmalloc: large alloc 3407765504 bytes == 0x7fc56efba000 @  0x7fc88a4f81e7 0x7fc8877785e1 0x7fc8877dcc78 0x7fc88777be61 0x551555 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588c8b 0x7fc8288f2e5c 0x59478c 0x59fd0e 0x5576d8 0x50c19e 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508f37 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp 'results/VA-CNN/NTU/VA/epoch26_val90.3345718383789_best.pth' '../drive/My Drive/resnext50_32x4d-CV-epoch26_val90.33.path'
