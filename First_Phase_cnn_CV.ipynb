# %% [markdown]
# <a href="https://colab.research.google.com/github/aidagh/Action-Recognition/blob/main/First_Phase_cnn_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi #show selected GPU
# Out:
# Wed Nov 18 04:35:24 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#Import Libraries
import shutil
import cv2
import numpy as np
import os
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
#Download Dataset from Kaggle
# !wget -cO - 'https://storage.googleapis.com/kaggle-data-sets/965291/1632787/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20201115%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20201115T053306Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...' > raw_data.zip

# %%
#Clone GitHub profile (CODES)
# !git clone 'https://github.com/mhrah7495/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition'

# %%
#UNZIP the dataset
shutil.unpack_archive('raw_data.zip', 'View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/raw_data', 'zip')

# %%
cd '/content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu'

# %%
# Remove the bad skeleton 
# !python get_raw_denoised_data.py

# %%
# Transform the skeleton to the center of the first frame
# !python seq_transformation.py --dataset='CV'
# Out:
# tcmalloc: large alloc 10184040448 bytes == 0x709ae000 @  0x7f5c8e80f001 0x7f5c8c333765 0x7f5c8c397bb0 0x7f5c8c399a4f 0x7f5c8c430048 0x50a4a5 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7f5c8e40abf7 0x5b259a
# tcmalloc: large alloc 6437347328 bytes == 0x2d01f0000 @  0x7f5c8e80d1e7 0x7f5c8c3335e1 0x7f5c8c397c78 0x7f5c8c397d93 0x7f5c8c422ed6 0x7f5c8c423338 0x50c19e 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7f5c8e40abf7 0x5b259a
# tcmalloc: large alloc 3407765504 bytes == 0x2d01f0000 @  0x7f5c8e80d1e7 0x7f5c8c3335e1 0x7f5c8c397c78 0x7f5c8c397d93 0x7f5c8c422ed6 0x7f5c8c423338 0x50c19e 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7f5c8e40abf7 0x5b259a

# %%
cd ..
# Out:
# /content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data

# %%
cd ..
# Out:
# /content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition

# %%
#Run CNN code (ResNet50)
# !python  va-cnn.py --model VA --train 1 --case=1 --max_epoches=30
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 111MB/s]
# tcmalloc: large alloc 6437347328 bytes == 0x7fb77e4de000 @  0x7fb9c99e01e7 0x7fb9c6c605e1 0x7fb9c6cc4c78 0x7fb9c6c63e61 0x551555 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588c8b 0x7fb96815ae5c 0x59478c 0x59fd0e 0x5576d8 0x50c19e 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508f37 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03
# tcmalloc: large alloc 3407765504 bytes == 0x7fb69efba000 @  0x7fb9c99e01e7 0x7fb9c6c605e1 0x7fb9c6cc4c78 0x7fb9c6c63e61 0x551555 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588c8b 0x7fb96815ae5c 0x59478c 0x59fd0e 0x5576d8 0x50c19e 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508f37 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03
# Train on 35763 samples, validate on 1883 samples
# ...

# %%
cd ..
# Out:
# /content

# %%
import shutil
shutil.make_archive('resnet50-reports-CV','zip','/content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/reports')
shutil.make_archive('resnet50-models-CV','zip','/content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/results')
# Out:
# '/content/resnet50-models-CV.zip'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp 'resnet50-reports-CV.zip' 'drive/My Drive'

# %%
import shutil
shutil.make_archive('resnet50-models-CV','zip','/content/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/results')

# %%
# !cp 'resnet50-reports-CV.zip' 'drive/My Drive'
# !cp 'resnet50-models-CV.zip' 'drive/My Drive'
